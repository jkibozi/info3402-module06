# %% [markdown]
# # INFO 3402 - Module Assignment 6
# ## (Module Assignment 5 Redux)
# [Jason Kibozi-Yocka](https://github.com/jkibozi)<br>
# University of Colorado Boulder<br>

# %%
import pandas as pd
import os
pd.options.display.max_columns = 200

# %% [markdown]
# ## Import my Datasets

# %%
# read in my data from csv files
usgreenhousegasDF = pd.read_csv('usgreenhousegas1990_2017.csv')
ushealthcarepricesDF = pd.read_csv('ushealthcareprices2008_2018.csv')
worldlifeexpectancyDF = pd.read_csv('worldlifeexpectancy1960_2017.csv')

# %%
# let's inspect our usgreenhousegas Dataframe
usgreenhousegasDF.head()
# Out:
#                  Gas         1990         1991         1992         1993  \
# 0     Carbon dioxide  5121.179440  5071.563914  5174.670601  5281.386608
# 1            Methane   779.845550   784.384856   783.176602   770.308404
# 2      Nitrous oxide   370.307694   368.961757   371.786442   385.347234
# 3  Fluorinated gases    99.667859    90.704668    95.300712    95.027350
# 4              Total  6371.000543  6315.615194  6424.934357  6532.069596
#
#           1994         1995         1996         1997         1998  \
# 0  5375.033803  5436.697986  5625.041885  5701.920919  5749.893056
# 1   775.160651   767.845344   759.491158   744.932926   729.618317
# 2   376.511527   388.502830   395.545749   386.608376   402.495771
# 3    98.129806   117.021137   127.620262   134.999750   150.518866
# 4  6624.835787  6710.067297  6907.699054  6968.461971  7032.526010
#
#           1999         2000         2001         2002         2003  \
# ...

# %%
usgreenhousegasDF.shape
# Out:
# (5, 29)

# %%
# let's inspect our ushealthcareprices Dataframe
ushealthcarepricesDF.head()
# Out:
#         Date  Price  GDP
# 0  12/1/2007    0.0  0.0
# 1   1/1/2008    0.5  0.2
# 2   2/1/2008    0.8  0.5
# 3   3/1/2008    0.9  0.6
# 4   4/1/2008    0.9  0.8

# %%
ushealthcarepricesDF.shape
# Out:
# (124, 3)

# %%
# let's inspect our uslifeexpectancy Dataframe
worldlifeexpectancyDF.head()
# Out:
#             Country_Name              Country_Code  Indicator_Name  \
# Aruba                ABW  Life expectancy at birth   total (years)
# Afghanistan          AFG  Life expectancy at birth   total (years)
# Angola               AGO  Life expectancy at birth   total (years)
# Albania              ALB  Life expectancy at birth   total (years)
# Andorra              AND  Life expectancy at birth   total (years)
#
#              Indicator Code    1960    1961    1962    1963    1964    1965  \
# Aruba        SP.DYN.LE00.IN  65.662  66.074  66.444  66.787  67.113  67.435
# Afghanistan  SP.DYN.LE00.IN  32.446  32.962  33.471  33.971  34.463  34.948
# Angola       SP.DYN.LE00.IN  37.524  37.811  38.113  38.430  38.760  39.102
# Albania      SP.DYN.LE00.IN  62.283  63.301  64.190  64.914  65.463  65.850
# Andorra      SP.DYN.LE00.IN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                1966    1967    1968    1969    1970    1971    1972    1973  \
# ...

# %%
worldlifeexpectancyDF.shape
# Out:
# (264, 65)

# %% [markdown]
# ## Clean my Datasets

# %% [markdown]
# ### [U.S. Greenhouse Gas Emissions by Gas, 1990-2017](https://cfpub.epa.gov/ghgdata/inventoryexplorer/)
# **United States Environmental Protection Agency (US EPA)**

# %%
# what does it look like right now?
usgreenhousegasDF.head()
# Out:
#                  Gas         1990         1991         1992         1993  \
# 0     Carbon dioxide  5121.179440  5071.563914  5174.670601  5281.386608
# 1            Methane   779.845550   784.384856   783.176602   770.308404
# 2      Nitrous oxide   370.307694   368.961757   371.786442   385.347234
# 3  Fluorinated gases    99.667859    90.704668    95.300712    95.027350
# 4              Total  6371.000543  6315.615194  6424.934357  6532.069596
#
#           1994         1995         1996         1997         1998  \
# 0  5375.033803  5436.697986  5625.041885  5701.920919  5749.893056
# 1   775.160651   767.845344   759.491158   744.932926   729.618317
# 2   376.511527   388.502830   395.545749   386.608376   402.495771
# 3    98.129806   117.021137   127.620262   134.999750   150.518866
# 4  6624.835787  6710.067297  6907.699054  6968.461971  7032.526010
#
#           1999         2000         2001         2002         2003  \
# ...

# %%
# let's use pandas' .melt() so that we can put the years into one column

# %%
usgreenhousegasRDF = usgreenhousegasDF.melt(id_vars=["Gas"],var_name="Year",value_name="Emission")

# %%
usgreenhousegasRDF.head()
# Out:
#                  Gas  Year     Emission
# 0     Carbon dioxide  1990  5121.179440
# 1            Methane  1990   779.845550
# 2      Nitrous oxide  1990   370.307694
# 3  Fluorinated gases  1990    99.667859
# 4              Total  1990  6371.000543

# %%
usgreenhousegasRDF.shape
# Out:
# (140, 3)

# %% [markdown]
# ### [Cumulative Percent Change in U.S. Heathcare Prices and GDP, 2007-2018](https://www.healthsystemtracker.org/chart-collection/how-have-healthcare-prices-grown-in-the-u-s-over-time/#item-prices-for-health-care-have-grown-faster-than-prices-in-the-general-economy)
# **Peterson-KFF Health System Tracker**

# %%
# what does it look like right now?
ushealthcarepricesDF.head()
# Out:
#         Date  Price  GDP
# 0  12/1/2007    0.0  0.0
# 1   1/1/2008    0.5  0.2
# 2   2/1/2008    0.8  0.5
# 3   3/1/2008    0.9  0.6
# 4   4/1/2008    0.9  0.8

# %%
# looks fine, let's move on

# %% [markdown]
# ### [U.S. Life Expectancy at Birth, 1960-2017](https://data.worldbank.org/indicator/SP.DYN.LE00.IN?locations=US)
# **The World Bank**

# %%
# what does it look like right now?
worldlifeexpectancyDF.head()
# Out:
#             Country_Name              Country_Code  Indicator_Name  \
# Aruba                ABW  Life expectancy at birth   total (years)
# Afghanistan          AFG  Life expectancy at birth   total (years)
# Angola               AGO  Life expectancy at birth   total (years)
# Albania              ALB  Life expectancy at birth   total (years)
# Andorra              AND  Life expectancy at birth   total (years)
#
#              Indicator Code    1960    1961    1962    1963    1964    1965  \
# Aruba        SP.DYN.LE00.IN  65.662  66.074  66.444  66.787  67.113  67.435
# Afghanistan  SP.DYN.LE00.IN  32.446  32.962  33.471  33.971  34.463  34.948
# Angola       SP.DYN.LE00.IN  37.524  37.811  38.113  38.430  38.760  39.102
# Albania      SP.DYN.LE00.IN  62.283  63.301  64.190  64.914  65.463  65.850
# Andorra      SP.DYN.LE00.IN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                1966    1967    1968    1969    1970    1971    1972    1973  \
# ...

# %%
# I only need the U.S. so let's uses pandas' .loc() to grab that row

# %%
uslifeexpectancyDF = worldlifeexpectancyDF.loc[worldlifeexpectancyDF['Country_Name'] == "USA"]

# %%
uslifeexpectancyDF.drop(columns=["Country_Name","Country_Code","Indicator_Name","Indicator Code","2018","2019","Unnamed: 64"],
                        inplace=True)
# Out:
# C:\Users\jkibo\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
uslifeexpectancyDF.head()
# Out:
#                            1960       1961       1962       1963       1964  \
# United States  69.7707317073171  70.270732  70.119512  69.917073  70.165854
#
#                     1965       1966       1967      1968       1969  \
# United States  70.214634  70.212195  70.560976  69.95122  70.507317
#
#                     1970       1971       1972       1973       1974  \
# United States  70.807317  71.107317  71.156098  71.356098  71.956098
#
#                     1975       1976       1977       1978       1979  \
# United States  72.604878  72.856098  73.256098  73.356098  73.804878
#
#                     1980       1981       1982       1983       1984  \
# United States  73.609756  74.009756  74.360976  74.463415  74.563415
#
#                     1985       1986       1987       1988       1989  \
# United States  74.563415  74.614634  74.765854  74.765854  75.017073
#
#                     1990       1991       1992       1993       1994  \
# ...

# %%
# let's combine the years into one column using pandas' .melt()

# %%
uslifeexpectancyDF = uslifeexpectancyDF.melt(var_name="Year",value_name="Life Expectancy")
uslifeexpectancyDF.head()
# Out:
#    Year   Life Expectancy
# 0  1960  69.7707317073171
# 1  1961           70.2707
# 2  1962           70.1195
# 3  1963           69.9171
# 4  1964           70.1659

# %% [markdown]
# ## Export my Cleaned Datasets

# %%
usgreenhousegasDF.to_csv("datasets/usgreenhousegasemission_alt.csv",index=False)
usgreenhousegasRDF.to_csv("datasets/usgreenhousegasemission.csv",index=False)
ushealthcarepricesDF.to_csv("datasets/ushealthcareprices.csv",index=False)
uslifeexpectancyDF.to_csv("datasets/uslifeexpectancy.csv",index=False)

# %% [markdown]
# ## Populate my MySQL Database

# %%
# following code is based upon code provided by Prof. Brian C. Keegan, Ph.D.

from sqlalchemy import create_engine

host = 'localhost'
port = 3306
user = 'root'

with open('pass.txt','r') as file:
    password = file.readline()

database = 'infoproj6'

engine = create_engine('mysql+mysqlconnector://{0}:{1}@{2}:{3}/{4}'.format(
    user,password,host,port,database),connect_args={'connect_timeout':1000})

conn = engine.connect()

# %%
# following code is based upon code provided by Prof. Brian C. Keegan, Ph.D.

files = os.listdir('./datasets/')
csv_files = [f for f in files if '.csv' in f]
db_tables = pd.read_sql_query('show tables',conn)['Tables_in_infoproj6'].tolist()

for f in csv_files:
    table_name = f.split('.csv')[0]
    
    if table_name not in db_tables:
        _df = pd.read_csv('./datasets/' + f)
        
        try:
            _df.to_sql(name = table_name,
                       con = conn,
                       if_exists = 'replace',
                       index = False,
                       chunksize = 1000000)
        
        except:
            print(table_name)
            pass

# %%
# It worked, now my sql database is populated with tables
pd.read_sql_query('show tables',conn)
# Out:
#            Tables_in_infoproj6
# 0      usgreenhousegasemission
# 1  usgreenhousegasemission_alt
# 2           ushealthcareprices
# 3             uslifeexpectancy
